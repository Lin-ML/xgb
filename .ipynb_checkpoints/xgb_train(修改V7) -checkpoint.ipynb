# %%
import pandas as pd
import optuna
import xgboost as xgb
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
#读取数据
df = pd.read_csv(r'C:/Users/Administrator/Desktop/dataV4.csv', encoding='gbk')

# %%
# 查看数据B
print(df.head())
# Out:
#    Blood Glucose  Maximum Blood Glucose  Minimum Blood Glucose  \
# 0           19.4                   19.4                   19.4
# 1           19.0                   19.4                   19.0
# 2           16.0                   19.4                   16.0
# 3           13.4                   19.4                   13.4
# 4            7.2                   19.4                    7.2
#
#    Mean Blood Glucose in Previous 24h  Number of Hypoglycemia Episodes  \
# 0                           19.400000                                0
# 1                           19.200000                                0
# 2                           18.133333                                0
# 3                           16.133333                                0
# 4                           12.200000                                0
#
#    Number of Hyperglycemia Episodes  Previous Blood Glucose Level  \
# 0                                 1                           NaN
# 1                                 2                          19.4
# 2                                 3                          19.0
# 3                                 4                          16.0
# 4                                 4                          13.4
#
#    Second Previous Blood Glucose Level   Age  Gender
# 0                                  NaN  7.26       1
# 1                                  NaN  7.26       1
# 2                                 19.4  7.26       1
# 3                                 19.0  7.26       1
# 4                                 16.0  7.26       1

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager

# 1. 查看系统可用字体列表，找到包含中文的字体
for font in font_manager.findSystemFonts(fontpaths=None, fontext='ttf'):
    print(font)

# 2. 设置matplotlib使用中文字体 (SimHei 是黑体)
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用黑体显示中文
plt.rcParams['axes.unicode_minus'] = False  # 解决负号 '-' 显示为方块的问题
# Out:
# C:\Windows\Fonts\impact.ttf
# C:\Windows\Fonts\DUBAI-LIGHT.TTF
# C:\Windows\Fonts\sylfaen.ttf
# C:\Windows\Fonts\LEELAWAD.TTF
# C:\Windows\Fonts\Nirmala.ttf
# C:\Windows\Fonts\monbaiti.ttf
# C:\Windows\Fonts\consola.ttf
# C:\Windows\Fonts\trebucit.ttf
# C:\Windows\Fonts\calibril.ttf
# C:\Windows\Fonts\mmrtext.ttf
# C:\Windows\Fonts\STLITI.TTF
# C:\Windows\Fonts\ntailub.ttf
# C:\Windows\Fonts\segoeuii.ttf
# C:\Windows\Fonts\tahoma.ttf
# C:\Windows\Fonts\ariali.ttf
# C:\Windows\Fonts\georgiab.ttf
# C:\Windows\Fonts\MSUIGHUB.TTF
# C:\Windows\Fonts\方正粗黑宋简体.ttf
# C:\Windows\Fonts\palai.ttf
# C:\Windows\Fonts\calibrii.ttf
# C:\Windows\Fonts\msyhl.ttc
# C:\Windows\Fonts\STFANGSO.TTF
# C:\Windows\Fonts\cambriaz.ttf
# C:\Windows\Fonts\Sitka.ttc
# C:\Windows\Fonts\IQYHT-Bold.ttf
# C:\Windows\Fonts\simfang.ttf
# C:\Windows\Fonts\Candaraz.ttf
# C:\Windows\Fonts\comicz.ttf
# C:\Windows\Fonts\palabi.ttf
# C:\Windows\Fonts\GOTHICBI.TTF
# C:\Windows\Fonts\Inkfree.ttf
# C:\Windows\Fonts\corbell.ttf
# C:\Windows\Fonts\Deng.ttf
# C:\Windows\Fonts\webdings.ttf
# C:\Windows\Fonts\SitkaI.ttc
# C:\Windows\Fonts\SitkaB.ttc
# C:\Windows\Fonts\PAPYRUS.TTF
# C:\Windows\Fonts\corbelli.ttf
# C:\Windows\Fonts\DUBAI-REGULAR.TTF
# C:\Windows\Fonts\seguisli.ttf
# C:\Windows\Fonts\BSSYM7.TTF
# C:\Windows\Fonts\comici.ttf
# C:\Windows\Fonts\consolaz.ttf
# C:\Windows\Fonts\taile.ttf
# C:\Windows\Fonts\FRSCRIPT.TTF
# C:\Windows\Fonts\STHUPO.TTF
# C:\Windows\Fonts\pala.ttf
# C:\Windows\Fonts\LHANDW.TTF
# C:\Windows\Fonts\Candarab.ttf
# C:\Windows\Fonts\GOTHIC.TTF
# C:\Windows\Fonts\BRADHITC.TTF
# C:\Windows\Fonts\STSONG.TTF
# C:\Windows\Fonts\segoeuiz.ttf
# C:\Windows\Fonts\segoeuisl.ttf
# C:\Windows\Fonts\Dengb.ttf
# C:\Windows\Fonts\cambriai.ttf
# C:\Windows\Fonts\seguihis.ttf
# C:\Windows\Fonts\SIMYOU.TTF
# C:\Windows\Fonts\IQYHT-Medium.ttf
# C:\Windows\Fonts\BKANT.TTF
# C:\Windows\Fonts\segoescb.ttf
# C:\ProgramData\kingsoft\office6\mtfont\mtextra.ttf
# C:\Windows\Fonts\framd.ttf
# C:\Windows\Fonts\DUBAI-BOLD.TTF
# C:\Windows\Fonts\DINNextLTPro-Bold.ttf
# C:\Windows\Fonts\ITCKRIST.TTF
# C:\Windows\Fonts\NirmalaB.ttf
# C:\Windows\Fonts\Candaral.ttf
# C:\Windows\Fonts\lucon.ttf
# C:\Windows\Fonts\DUBAI-MEDIUM.TTF
# C:\Windows\Fonts\STXINWEI.TTF
# C:\Windows\Fonts\l_10646.ttf
# C:\Windows\Fonts\arialbd.ttf
# C:\Windows\Fonts\times.ttf

# %%
# 使用seaborn绘制KDE图
sns.kdeplot(df['Blood Glucose'], fill=True)  # fill=True表示填充区域
# 添加标题和轴标签
plt.title('Density Plot of blood_sugar')
plt.xlabel('Value')
plt.ylabel('Density')
# 显示图形
plt.show()
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# 删除含有 NaN 或空值的行
df.dropna(inplace=True)

# %%
# 分离目标变量
target = df['Blood Glucose']
# 将“血糖值“， ”住院流水号“， ”测量时间“， ”频次“删除掉
df = df[['Maximum Blood Glucose', 'Minimum Blood Glucose', 'Mean Blood Glucose in Previous 24h', 
         'Number of Hypoglycemia Episodes', 'Number of Hyperglycemia Episodes', 
         'Previous Blood Glucose Level', 'Second Previous Blood Glucose Level','Age','Gender']]

# %%
print(df.head())
# Out:
#    Maximum Blood Glucose  Minimum Blood Glucose  \
# 2                   19.4                   16.0
# 3                   19.4                   13.4
# 4                   19.4                    7.2
# 5                   19.4                    7.2
# 6                   19.4                    5.0
#
#    Mean Blood Glucose in Previous 24h  Number of Hypoglycemia Episodes  \
# 2                           18.133333                                0
# 3                           16.133333                                0
# 4                           12.200000                                0
# 5                            9.333333                                0
# 6                            6.533333                                0
#
#    Number of Hyperglycemia Episodes  Previous Blood Glucose Level  \
# 2                                 3                          19.0
# 3                                 4                          16.0
# 4                                 4                          13.4
# 5                                 4                           7.2
# 6                                 4                           7.4
#
#    Second Previous Blood Glucose Level   Age  Gender
# 2                                 19.4  7.26       1
# 3                                 19.0  7.26       1
# 4                                 16.0  7.26       1
# 5                                 13.4  7.26       1
# 6                                  7.2  7.26       1

# %%
# 拆分数据集
train_x, test_x, train_y, test_y = train_test_split(df, target, test_size=0.2, random_state=42)

# %%
train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.25, random_state=42)

# %%
def r2_score(y_true, y_pred):
    return 1 - ((y_true - y_pred) ** 2).mean() / ((y_true - y_true.mean()) ** 2).mean()

# 将自定义评估函数封装成 XGBoost 可识别的形式
def custom_r2_score(y_true, y_pred):
    y_true = y_true.get_label()
    y_pred = y_pred
    return 'r2', r2_score(y_true, y_pred)

# %%
best_params = {
    'booster': 'gbtree',
    'learning_rate': 0.17161713216911806,
    'max_depth': 3,
    'min_child_weight': 1,
    'subsample': 0.9205290305290692,
    'colsample_bytree': 0.9695174733247519,
    'reg_alpha': 0.32309787954216,
    'reg_lambda': 5.505046834003221e-08,
    'gamma': 0.0009744840445500341,
    'n_estimators': 443*7
}

# %%
 model = xgb.XGBRegressor(**best_params)

# %%
eval_set = [(train_x, train_y), (valid_x, valid_y)]

# %%
print(train_x.head(5))
# Out:
#        Maximum Blood Glucose  Minimum Blood Glucose  \
# 33393                   23.9                    4.7
# 28988                   32.9                    8.9
# 46466                   11.2                    5.1
# 20228                   21.7                    7.0
# 3469                    25.5                    9.4
#
#        Mean Blood Glucose in Previous 24h  Number of Hypoglycemia Episodes  \
# 33393                           14.266667                                0
# 28988                            9.833333                                0
# 46466                            9.033333                                0
# 20228                           15.066667                                0
# 3469                            16.633333                                0
#
#        Number of Hyperglycemia Episodes  Previous Blood Glucose Level  \
# 33393                                25                          14.2
# 28988                                 7                          11.3
# 46466                                 1                           9.9
# 20228                                35                          13.8
# 3469                                 41                          17.1
#
#        Second Previous Blood Glucose Level    Age  Gender
# 33393                                 13.0   4.56       0
# 28988                                  9.3  13.42       1
# 46466                                 10.4  11.38       0
# 20228                                 13.3  10.92       0
# 3469                                  22.6   8.12       0

# %%
print(train_y.head(5))
# Out:
# 33393    15.6
# 28988     8.9
# 46466     6.8
# 20228    18.1
# 3469     10.2
# Name: Blood Glucose, dtype: float64

# %%
model.fit(train_x, train_y,
          eval_set=eval_set,
          verbose=True)
# Out:
# [0]	validation_0-rmse:4.49291	validation_1-rmse:4.52074
# [1]	validation_0-rmse:4.30642	validation_1-rmse:4.33145
# [2]	validation_0-rmse:3.96632	validation_1-rmse:3.99042
# [3]	validation_0-rmse:3.66944	validation_1-rmse:3.69161
# [4]	validation_0-rmse:3.42921	validation_1-rmse:3.44818
# [5]	validation_0-rmse:3.23271	validation_1-rmse:3.25369
# [6]	validation_0-rmse:3.08054	validation_1-rmse:3.10393
# [7]	validation_0-rmse:2.94846	validation_1-rmse:2.97666
# [8]	validation_0-rmse:2.84204	validation_1-rmse:2.87033
# [9]	validation_0-rmse:2.75723	validation_1-rmse:2.78657
# [424]	validation_0-rmse:0.30486	validation_1-rmse:0.41633
# [425]	validation_0-rmse:0.30417	validation_1-rmse:0.41592
# [426]	validation_0-rmse:0.30344	validation_1-rmse:0.41543
# [427]	validation_0-rmse:0.30292	validation_1-rmse:0.41495
# [428]	validation_0-rmse:0.30283	validation_1-rmse:0.41488
# [429]	validation_0-rmse:0.30257	validation_1-rmse:0.41468
# [430]	validation_0-rmse:0.30249	validation_1-rmse:0.41433
# [431]	validation_0-rmse:0.30238	validation_1-rmse:0.41446
# [432]	validation_0-rmse:0.30218	validation_1-rmse:0.41420
# [433]	validation_0-rmse:0.30188	validation_1-rmse:0.41403
# [434]	validation_0-rmse:0.30157	validation_1-rmse:0.41300
# [435]	validation_0-rmse:0.30122	validation_1-rmse:0.41280
# [436]	validation_0-rmse:0.30114	validation_1-rmse:0.41273
# [437]	validation_0-rmse:0.30101	validation_1-rmse:0.41264
# [438]	validation_0-rmse:0.30079	validation_1-rmse:0.41247
# [439]	validation_0-rmse:0.30058	validation_1-rmse:0.41240
# [440]	validation_0-rmse:0.30051	validation_1-rmse:0.41237
# [441]	validation_0-rmse:0.30036	validation_1-rmse:0.41290
# [442]	validation_0-rmse:0.30029	validation_1-rmse:0.41285
# [443]	validation_0-rmse:0.30002	validation_1-rmse:0.41258
# [444]	validation_0-rmse:0.29997	validation_1-rmse:0.41251
# [445]	validation_0-rmse:0.29971	validation_1-rmse:0.41236
# [446]	validation_0-rmse:0.29961	validation_1-rmse:0.41231
# [447]	validation_0-rmse:0.29953	validation_1-rmse:0.41238
# [448]	validation_0-rmse:0.29938	validation_1-rmse:0.41235
# [449]	validation_0-rmse:0.29914	validation_1-rmse:0.41096
# [450]	validation_0-rmse:0.29892	validation_1-rmse:0.40972
# [451]	validation_0-rmse:0.29879	validation_1-rmse:0.40971
# [452]	validation_0-rmse:0.29863	validation_1-rmse:0.40996
# [453]	validation_0-rmse:0.29850	validation_1-rmse:0.41001
# [454]	validation_0-rmse:0.29838	validation_1-rmse:0.40983
# [455]	validation_0-rmse:0.29829	validation_1-rmse:0.41013
# [456]	validation_0-rmse:0.29821	validation_1-rmse:0.41012
# [457]	validation_0-rmse:0.29768	validation_1-rmse:0.40975
# [458]	validation_0-rmse:0.29719	validation_1-rmse:0.40939
# [459]	validation_0-rmse:0.29687	validation_1-rmse:0.40909
# [460]	validation_0-rmse:0.29666	validation_1-rmse:0.40888
# [461]	validation_0-rmse:0.29648	validation_1-rmse:0.40924
# [462]	validation_0-rmse:0.29598	validation_1-rmse:0.40883
# [463]	validation_0-rmse:0.29573	validation_1-rmse:0.40869
# [464]	validation_0-rmse:0.29542	validation_1-rmse:0.40873
# [465]	validation_0-rmse:0.29502	validation_1-rmse:0.40844
# [466]	validation_0-rmse:0.29437	validation_1-rmse:0.40788
# [467]	validation_0-rmse:0.29394	validation_1-rmse:0.40760
# [468]	validation_0-rmse:0.29384	validation_1-rmse:0.40756
# [469]	validation_0-rmse:0.29366	validation_1-rmse:0.40741
# [2853]	validation_0-rmse:0.15057	validation_1-rmse:0.33179
# [2854]	validation_0-rmse:0.15056	validation_1-rmse:0.33179
# [2855]	validation_0-rmse:0.15055	validation_1-rmse:0.33182
# [2856]	validation_0-rmse:0.15054	validation_1-rmse:0.33182
# [2857]	validation_0-rmse:0.15052	validation_1-rmse:0.33181
# [2858]	validation_0-rmse:0.15051	validation_1-rmse:0.33181
# [2859]	validation_0-rmse:0.15050	validation_1-rmse:0.33180
# [2860]	validation_0-rmse:0.15048	validation_1-rmse:0.33179
# [2861]	validation_0-rmse:0.15046	validation_1-rmse:0.33177
# [2862]	validation_0-rmse:0.15045	validation_1-rmse:0.33177
# [2863]	validation_0-rmse:0.15044	validation_1-rmse:0.33178
# [2864]	validation_0-rmse:0.15040	validation_1-rmse:0.33174
# [2865]	validation_0-rmse:0.15038	validation_1-rmse:0.33174
# [2866]	validation_0-rmse:0.15037	validation_1-rmse:0.33173
# [2867]	validation_0-rmse:0.15036	validation_1-rmse:0.33172
# [2868]	validation_0-rmse:0.15034	validation_1-rmse:0.33172
# [2869]	validation_0-rmse:0.15032	validation_1-rmse:0.33171
# [2870]	validation_0-rmse:0.15031	validation_1-rmse:0.33173
# [2871]	validation_0-rmse:0.15030	validation_1-rmse:0.33170
# [2872]	validation_0-rmse:0.15028	validation_1-rmse:0.33168
# [2873]	validation_0-rmse:0.15021	validation_1-rmse:0.33163
# [2874]	validation_0-rmse:0.15021	validation_1-rmse:0.33155
# [2875]	validation_0-rmse:0.15020	validation_1-rmse:0.33155
# [2876]	validation_0-rmse:0.15018	validation_1-rmse:0.33152
# [2877]	validation_0-rmse:0.15017	validation_1-rmse:0.33154
# [2878]	validation_0-rmse:0.15016	validation_1-rmse:0.33155
# [2879]	validation_0-rmse:0.15014	validation_1-rmse:0.33153
# [2880]	validation_0-rmse:0.15013	validation_1-rmse:0.33154
# [2881]	validation_0-rmse:0.15012	validation_1-rmse:0.33151
# [2882]	validation_0-rmse:0.15007	validation_1-rmse:0.33150
# [2883]	validation_0-rmse:0.15005	validation_1-rmse:0.33150
# [2884]	validation_0-rmse:0.15003	validation_1-rmse:0.33150
# [2885]	validation_0-rmse:0.15000	validation_1-rmse:0.33155
# [2886]	validation_0-rmse:0.14999	validation_1-rmse:0.33154
# [2887]	validation_0-rmse:0.14998	validation_1-rmse:0.33155
# [2888]	validation_0-rmse:0.14997	validation_1-rmse:0.33160
# [2889]	validation_0-rmse:0.14996	validation_1-rmse:0.33158
# [2890]	validation_0-rmse:0.14995	validation_1-rmse:0.33154
# [2891]	validation_0-rmse:0.14993	validation_1-rmse:0.33158
# [2892]	validation_0-rmse:0.14992	validation_1-rmse:0.33162
# [2893]	validation_0-rmse:0.14991	validation_1-rmse:0.33162
# [2894]	validation_0-rmse:0.14989	validation_1-rmse:0.33162
# [2895]	validation_0-rmse:0.14988	validation_1-rmse:0.33154
# [2896]	validation_0-rmse:0.14984	validation_1-rmse:0.33151
# [2897]	validation_0-rmse:0.14980	validation_1-rmse:0.33150
# [2898]	validation_0-rmse:0.14976	validation_1-rmse:0.33148
# [2899]	validation_0-rmse:0.14975	validation_1-rmse:0.33151
# [2900]	validation_0-rmse:0.14974	validation_1-rmse:0.33152
# [2901]	validation_0-rmse:0.14972	validation_1-rmse:0.33152
# [2902]	validation_0-rmse:0.14971	validation_1-rmse:0.33152
# [2903]	validation_0-rmse:0.14967	validation_1-rmse:0.33151
# [2904]	validation_0-rmse:0.14962	validation_1-rmse:0.33149
# [2905]	validation_0-rmse:0.14960	validation_1-rmse:0.33151
# [2906]	validation_0-rmse:0.14956	validation_1-rmse:0.33150
# [2907]	validation_0-rmse:0.14955	validation_1-rmse:0.33150
# [2908]	validation_0-rmse:0.14953	validation_1-rmse:0.33149
# [2909]	validation_0-rmse:0.14952	validation_1-rmse:0.33150
# [2910]	validation_0-rmse:0.14949	validation_1-rmse:0.33149
# [2911]	validation_0-rmse:0.14947	validation_1-rmse:0.33148
# [2912]	validation_0-rmse:0.14945	validation_1-rmse:0.33146
# [2913]	validation_0-rmse:0.14943	validation_1-rmse:0.33147
# [2914]	validation_0-rmse:0.14942	validation_1-rmse:0.33149
# [2915]	validation_0-rmse:0.14941	validation_1-rmse:0.33149
# [2916]	validation_0-rmse:0.14941	validation_1-rmse:0.33146
# [2917]	validation_0-rmse:0.14940	validation_1-rmse:0.33145
# [2918]	validation_0-rmse:0.14938	validation_1-rmse:0.33145
# [2919]	validation_0-rmse:0.14937	validation_1-rmse:0.33147
# [2920]	validation_0-rmse:0.14935	validation_1-rmse:0.33144
# [2921]	validation_0-rmse:0.14934	validation_1-rmse:0.33145
# [2922]	validation_0-rmse:0.14932	validation_1-rmse:0.33138
# [2923]	validation_0-rmse:0.14931	validation_1-rmse:0.33137
# [2924]	validation_0-rmse:0.14928	validation_1-rmse:0.33137
# [2925]	validation_0-rmse:0.14927	validation_1-rmse:0.33134
# [2926]	validation_0-rmse:0.14925	validation_1-rmse:0.33135
# [2927]	validation_0-rmse:0.14924	validation_1-rmse:0.33135
# [2928]	validation_0-rmse:0.14919	validation_1-rmse:0.33131
# [2929]	validation_0-rmse:0.14916	validation_1-rmse:0.33129
# [2930]	validation_0-rmse:0.14914	validation_1-rmse:0.33127
# [2931]	validation_0-rmse:0.14913	validation_1-rmse:0.33123
# [2932]	validation_0-rmse:0.14912	validation_1-rmse:0.33123
# [2933]	validation_0-rmse:0.14910	validation_1-rmse:0.33121
# [2934]	validation_0-rmse:0.14908	validation_1-rmse:0.33122
# [2935]	validation_0-rmse:0.14907	validation_1-rmse:0.33123
# [2936]	validation_0-rmse:0.14906	validation_1-rmse:0.33124
# [2937]	validation_0-rmse:0.14905	validation_1-rmse:0.33123
# [2938]	validation_0-rmse:0.14903	validation_1-rmse:0.33125
# [2939]	validation_0-rmse:0.14901	validation_1-rmse:0.33124
# [2940]	validation_0-rmse:0.14900	validation_1-rmse:0.33120
# [2941]	validation_0-rmse:0.14897	validation_1-rmse:0.33119
# [2942]	validation_0-rmse:0.14897	validation_1-rmse:0.33119
# [2943]	validation_0-rmse:0.14896	validation_1-rmse:0.33117
# [2944]	validation_0-rmse:0.14895	validation_1-rmse:0.33119
# [2945]	validation_0-rmse:0.14892	validation_1-rmse:0.33111
# [2946]	validation_0-rmse:0.14891	validation_1-rmse:0.33111
# [2947]	validation_0-rmse:0.14890	validation_1-rmse:0.33116
# [2948]	validation_0-rmse:0.14889	validation_1-rmse:0.33117
# [2949]	validation_0-rmse:0.14888	validation_1-rmse:0.33118
# [2950]	validation_0-rmse:0.14886	validation_1-rmse:0.33122
# [2951]	validation_0-rmse:0.14880	validation_1-rmse:0.33118
# [2952]	validation_0-rmse:0.14879	validation_1-rmse:0.33120
# [2953]	validation_0-rmse:0.14878	validation_1-rmse:0.33119
# [2954]	validation_0-rmse:0.14877	validation_1-rmse:0.33119
# [2955]	validation_0-rmse:0.14875	validation_1-rmse:0.33120
# [2956]	validation_0-rmse:0.14869	validation_1-rmse:0.33117
# [2957]	validation_0-rmse:0.14864	validation_1-rmse:0.33114
# [2958]	validation_0-rmse:0.14862	validation_1-rmse:0.33114
# [2959]	validation_0-rmse:0.14857	validation_1-rmse:0.33113
# [2960]	validation_0-rmse:0.14856	validation_1-rmse:0.33107
# [2961]	validation_0-rmse:0.14855	validation_1-rmse:0.33106
# [2962]	validation_0-rmse:0.14853	validation_1-rmse:0.33105
# [2963]	validation_0-rmse:0.14852	validation_1-rmse:0.33104
# [2964]	validation_0-rmse:0.14851	validation_1-rmse:0.33103
# [2965]	validation_0-rmse:0.14849	validation_1-rmse:0.33106
# [2966]	validation_0-rmse:0.14844	validation_1-rmse:0.33103
# [2967]	validation_0-rmse:0.14842	validation_1-rmse:0.33094
# [2968]	validation_0-rmse:0.14840	validation_1-rmse:0.33096
# [2969]	validation_0-rmse:0.14838	validation_1-rmse:0.33097
# [2970]	validation_0-rmse:0.14837	validation_1-rmse:0.33095
# [2971]	validation_0-rmse:0.14835	validation_1-rmse:0.33094
# [2972]	validation_0-rmse:0.14834	validation_1-rmse:0.33093
# [2973]	validation_0-rmse:0.14833	validation_1-rmse:0.33092
# [2974]	validation_0-rmse:0.14832	validation_1-rmse:0.33090
# [2975]	validation_0-rmse:0.14829	validation_1-rmse:0.33090
# [2976]	validation_0-rmse:0.14828	validation_1-rmse:0.33090
# [2977]	validation_0-rmse:0.14827	validation_1-rmse:0.33088
# [2978]	validation_0-rmse:0.14823	validation_1-rmse:0.33086
# [2979]	validation_0-rmse:0.14820	validation_1-rmse:0.33085
# [2980]	validation_0-rmse:0.14804	validation_1-rmse:0.33077
# [2981]	validation_0-rmse:0.14803	validation_1-rmse:0.33080
# [2982]	validation_0-rmse:0.14802	validation_1-rmse:0.33081
# [2983]	validation_0-rmse:0.14799	validation_1-rmse:0.33080
# [2984]	validation_0-rmse:0.14797	validation_1-rmse:0.33079
# [2985]	validation_0-rmse:0.14793	validation_1-rmse:0.33078
# [2986]	validation_0-rmse:0.14792	validation_1-rmse:0.33084
# [2987]	validation_0-rmse:0.14792	validation_1-rmse:0.33082
# [2988]	validation_0-rmse:0.14791	validation_1-rmse:0.33083
# [2989]	validation_0-rmse:0.14789	validation_1-rmse:0.33083
# [2990]	validation_0-rmse:0.14788	validation_1-rmse:0.33083
# [2991]	validation_0-rmse:0.14786	validation_1-rmse:0.33081
# [2992]	validation_0-rmse:0.14785	validation_1-rmse:0.33080
# [2993]	validation_0-rmse:0.14782	validation_1-rmse:0.33078
# [2994]	validation_0-rmse:0.14782	validation_1-rmse:0.33082
# [2995]	validation_0-rmse:0.14781	validation_1-rmse:0.33088
# [2996]	validation_0-rmse:0.14779	validation_1-rmse:0.33085
# [2997]	validation_0-rmse:0.14778	validation_1-rmse:0.33083
# [2998]	validation_0-rmse:0.14776	validation_1-rmse:0.33082
# [2999]	validation_0-rmse:0.14775	validation_1-rmse:0.33083
# [3000]	validation_0-rmse:0.14774	validation_1-rmse:0.33083
# [3001]	validation_0-rmse:0.14772	validation_1-rmse:0.33082
# [3002]	validation_0-rmse:0.14771	validation_1-rmse:0.33082
# [3003]	validation_0-rmse:0.14768	validation_1-rmse:0.33080
# [3004]	validation_0-rmse:0.14768	validation_1-rmse:0.33079
# [3005]	validation_0-rmse:0.14766	validation_1-rmse:0.33078
# [3006]	validation_0-rmse:0.14764	validation_1-rmse:0.33077
# [3007]	validation_0-rmse:0.14763	validation_1-rmse:0.33081
# [3008]	validation_0-rmse:0.14759	validation_1-rmse:0.33078
# [3009]	validation_0-rmse:0.14757	validation_1-rmse:0.33078
# [3010]	validation_0-rmse:0.14755	validation_1-rmse:0.33077
# [3011]	validation_0-rmse:0.14755	validation_1-rmse:0.33076
# [3012]	validation_0-rmse:0.14754	validation_1-rmse:0.33077
# [3013]	validation_0-rmse:0.14752	validation_1-rmse:0.33077
# [3014]	validation_0-rmse:0.14749	validation_1-rmse:0.33076
# [3015]	validation_0-rmse:0.14748	validation_1-rmse:0.33076
# [3016]	validation_0-rmse:0.14747	validation_1-rmse:0.33085
# [3017]	validation_0-rmse:0.14746	validation_1-rmse:0.33083
# [3018]	validation_0-rmse:0.14744	validation_1-rmse:0.33082
# [3019]	validation_0-rmse:0.14743	validation_1-rmse:0.33081
# [3020]	validation_0-rmse:0.14742	validation_1-rmse:0.33080
# [3021]	validation_0-rmse:0.14740	validation_1-rmse:0.33080
# [3022]	validation_0-rmse:0.14739	validation_1-rmse:0.33079
# [3023]	validation_0-rmse:0.14738	validation_1-rmse:0.33079
# [3024]	validation_0-rmse:0.14734	validation_1-rmse:0.33077
# [3025]	validation_0-rmse:0.14733	validation_1-rmse:0.33079
# [3026]	validation_0-rmse:0.14732	validation_1-rmse:0.33080
# [3027]	validation_0-rmse:0.14730	validation_1-rmse:0.33079
# [3028]	validation_0-rmse:0.14723	validation_1-rmse:0.33075
# [3029]	validation_0-rmse:0.14723	validation_1-rmse:0.33074
# [3030]	validation_0-rmse:0.14720	validation_1-rmse:0.33074
# [3031]	validation_0-rmse:0.14719	validation_1-rmse:0.33075
# [3032]	validation_0-rmse:0.14716	validation_1-rmse:0.33074
# [3033]	validation_0-rmse:0.14715	validation_1-rmse:0.33074
# [3034]	validation_0-rmse:0.14714	validation_1-rmse:0.33074
# [3035]	validation_0-rmse:0.14712	validation_1-rmse:0.33073
# [3036]	validation_0-rmse:0.14711	validation_1-rmse:0.33074
# [3037]	validation_0-rmse:0.14707	validation_1-rmse:0.33072
# [3038]	validation_0-rmse:0.14706	validation_1-rmse:0.33079
# [3039]	validation_0-rmse:0.14702	validation_1-rmse:0.33076
# [3040]	validation_0-rmse:0.14700	validation_1-rmse:0.33076
# [3041]	validation_0-rmse:0.14699	validation_1-rmse:0.33079
# [3042]	validation_0-rmse:0.14698	validation_1-rmse:0.33078
# [3043]	validation_0-rmse:0.14696	validation_1-rmse:0.33077
# [3044]	validation_0-rmse:0.14695	validation_1-rmse:0.33073
# [3045]	validation_0-rmse:0.14695	validation_1-rmse:0.33072
# [3046]	validation_0-rmse:0.14693	validation_1-rmse:0.33072
# [3047]	validation_0-rmse:0.14692	validation_1-rmse:0.33070
# [3048]	validation_0-rmse:0.14691	validation_1-rmse:0.33065
# [3049]	validation_0-rmse:0.14685	validation_1-rmse:0.33061
# [3050]	validation_0-rmse:0.14685	validation_1-rmse:0.33063
# [3051]	validation_0-rmse:0.14684	validation_1-rmse:0.33057
# [3052]	validation_0-rmse:0.14683	validation_1-rmse:0.33057
# [3053]	validation_0-rmse:0.14682	validation_1-rmse:0.33055
# [3054]	validation_0-rmse:0.14681	validation_1-rmse:0.33055
# [3055]	validation_0-rmse:0.14680	validation_1-rmse:0.33053
# [3056]	validation_0-rmse:0.14678	validation_1-rmse:0.33051
# [3057]	validation_0-rmse:0.14677	validation_1-rmse:0.33052
# [3058]	validation_0-rmse:0.14673	validation_1-rmse:0.33051
# [3059]	validation_0-rmse:0.14672	validation_1-rmse:0.33051
# [3060]	validation_0-rmse:0.14671	validation_1-rmse:0.33052
# [3061]	validation_0-rmse:0.14661	validation_1-rmse:0.33046
# [3062]	validation_0-rmse:0.14659	validation_1-rmse:0.33045
# [3063]	validation_0-rmse:0.14658	validation_1-rmse:0.33043
# [3064]	validation_0-rmse:0.14656	validation_1-rmse:0.33044
# [3065]	validation_0-rmse:0.14655	validation_1-rmse:0.33048
# [3066]	validation_0-rmse:0.14654	validation_1-rmse:0.33048
# [3067]	validation_0-rmse:0.14654	validation_1-rmse:0.33046
# [3068]	validation_0-rmse:0.14653	validation_1-rmse:0.33046
# [3069]	validation_0-rmse:0.14651	validation_1-rmse:0.33045
# [3070]	validation_0-rmse:0.14645	validation_1-rmse:0.33041
# [3071]	validation_0-rmse:0.14644	validation_1-rmse:0.33041
# [3072]	validation_0-rmse:0.14642	validation_1-rmse:0.33039
# [3073]	validation_0-rmse:0.14641	validation_1-rmse:0.33038
# [3074]	validation_0-rmse:0.14640	validation_1-rmse:0.33038
# [3075]	validation_0-rmse:0.14638	validation_1-rmse:0.33038
# [3076]	validation_0-rmse:0.14633	validation_1-rmse:0.33036
# [3077]	validation_0-rmse:0.14628	validation_1-rmse:0.33035
# [3078]	validation_0-rmse:0.14627	validation_1-rmse:0.33034
# [3079]	validation_0-rmse:0.14626	validation_1-rmse:0.33034
# [3080]	validation_0-rmse:0.14624	validation_1-rmse:0.33034
# [3081]	validation_0-rmse:0.14622	validation_1-rmse:0.33032
# [3082]	validation_0-rmse:0.14619	validation_1-rmse:0.33030
# [3083]	validation_0-rmse:0.14618	validation_1-rmse:0.33034
# [3084]	validation_0-rmse:0.14617	validation_1-rmse:0.33035
# [3085]	validation_0-rmse:0.14616	validation_1-rmse:0.33034
# [3086]	validation_0-rmse:0.14614	validation_1-rmse:0.33034
# [3087]	validation_0-rmse:0.14613	validation_1-rmse:0.33034
# [3088]	validation_0-rmse:0.14611	validation_1-rmse:0.33034
# [3089]	validation_0-rmse:0.14610	validation_1-rmse:0.33031
# [3090]	validation_0-rmse:0.14605	validation_1-rmse:0.33029
# [3091]	validation_0-rmse:0.14604	validation_1-rmse:0.33027
# [3092]	validation_0-rmse:0.14602	validation_1-rmse:0.33026
# [3093]	validation_0-rmse:0.14599	validation_1-rmse:0.33024
# [3094]	validation_0-rmse:0.14598	validation_1-rmse:0.33023
# [3095]	validation_0-rmse:0.14596	validation_1-rmse:0.33028
# [3096]	validation_0-rmse:0.14595	validation_1-rmse:0.33029
# [3097]	validation_0-rmse:0.14590	validation_1-rmse:0.33027
# [3098]	validation_0-rmse:0.14588	validation_1-rmse:0.33027
# [3099]	validation_0-rmse:0.14586	validation_1-rmse:0.33026
# [3100]	validation_0-rmse:0.14582	validation_1-rmse:0.33024
# XGBRegressor(base_score=None, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9695174733247519, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0.0009744840445500341,
#              grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.17161713216911806,
#              max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=3101, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
#训练
y_pred_train = model.predict(train_x)
mse_train = mean_squared_error(train_y, y_pred_train) #均方误差
R2_train = r2_score(train_y, y_pred_train)
print(f"Mean Squared Error: {mse_train}")
print(f"R2_train: {r2_score(train_y, y_pred_train)}")
# Out:
# Mean Squared Error: 0.02126309668281649
# R2_train: 0.999152967394609

# %%
#均方根误差 (RMSE)  平均绝对误差 (MAE)
rmse_train = np.sqrt(mse_train)
mae_train = mean_absolute_error(train_y, y_pred_train)
print(f"Root Mean Squared Error : {rmse_train}")
print(f"Mean Absolute Error : {mae_train}")
# Out:
# Root Mean Squared Error : 0.14581871170332183
# Mean Absolute Error : 0.11234845224161201

# %%
#验证
y_pred_valid = model.predict(valid_x)
mse_valid = mean_squared_error(valid_y, y_pred_valid) #均方误差
R2_vaild = r2_score(valid_y, y_pred_valid)
print(f"Mean Squared Error: {mse_valid}")
print(f"R2_valid: {r2_score(valid_y, y_pred_valid)}")
# Out:
# Mean Squared Error: 0.1090607427307328
# R2_valid: 0.9957099093922623

# %%
#均方根误差 (RMSE)  平均绝对误差 (MAE)
rmse_valid = np.sqrt(mse_valid)
mae_valid = mean_absolute_error(valid_y, y_pred_valid)
print(f"Root Mean Squared Error : {rmse_valid}")
print(f"Mean Absolute Error : {mae_valid}")
# Out:
# Root Mean Squared Error : 0.33024345978494835
# Mean Absolute Error : 0.16370829972406187

# %%
# 保存模型
model.save_model('final_xgb_model.json')

# %%
model = xgb.XGBRegressor()

# %%
# 加载模型
model.load_model('final_xgb_model.json')

# %%
# 预测并评估
y_pred_test = model.predict(test_x)
mse_test = mean_squared_error(test_y, y_pred_test)
R2_test=r2_score(test_y, y_pred_test)
print(f"Mean Squared Error: {mse_test}")
print(f"R2_test: {r2_score(test_y, y_pred_test)}")
# Out:
# Mean Squared Error: 0.1015371662762387
# R2_test: 0.9959519547748389

# %%
#均方根误差 (RMSE)  平均绝对误差 (MAE)
rmse_test = np.sqrt(mse_test)
mae_test = mean_absolute_error(test_y, y_pred_test)
print(f"Root Mean Squared Error : {rmse_test}")
print(f"Mean Absolute Error : {mae_test}")
# Out:
# Root Mean Squared Error : 0.3186489703046892
# Mean Absolute Error : 0.161820318037049

# %%
print(test_y.head(10))
# Out:
# 12420    25.1
# 4332     17.0
# 18458     7.5
# 48708    15.0
# 40435     8.3
# 42261     4.7
# 37484     7.4
# 20533    20.1
# 46890    11.3
# 29510    10.9
# Name: Blood Glucose, dtype: float64

# %%
#测试集进行预测
print(y_pred_test[:10])
# Out:
# [24.904827  16.75092    7.5908203 14.824188   8.318793   4.803465
#   7.911677  20.051266  11.47939   10.696398 ]

# %%
print(df.head())
# Out:
#    Maximum Blood Glucose  Minimum Blood Glucose  \
# 2                   19.4                   16.0
# 3                   19.4                   13.4
# 4                   19.4                    7.2
# 5                   19.4                    7.2
# 6                   19.4                    5.0
#
#    Mean Blood Glucose in Previous 24h  Number of Hypoglycemia Episodes  \
# 2                           18.133333                                0
# 3                           16.133333                                0
# 4                           12.200000                                0
# 5                            9.333333                                0
# 6                            6.533333                                0
#
#    Number of Hyperglycemia Episodes  Previous Blood Glucose Level  \
# 2                                 3                          19.0
# 3                                 4                          16.0
# 4                                 4                          13.4
# 5                                 4                           7.2
# 6                                 4                           7.4
#
#    Second Previous Blood Glucose Level   Age  Gender
# 2                                 19.4  7.26       1
# 3                                 19.0  7.26       1
# 4                                 16.0  7.26       1
# 5                                 13.4  7.26       1
# 6                                  7.2  7.26       1

# %% [markdown]
# ## 1.模型指标可视化

# %%
# 将指标放入列表
metrics_labels = ['MSE', 'RMSE', 'MAE', 'R-squared']
train_metrics = [mse_train, rmse_train, mae_train, R2_train]
valid_metrics = [mse_valid, rmse_valid, mae_valid, R2_vaild]
test_metrics = [mse_test, rmse_test, mae_test, R2_test]

# %%
# 创建柱状图
x = np.arange(len(metrics_labels))  # 横坐标位置
width = 0.25# 柱子的宽度


fig, ax = plt.subplots(figsize=(8, 6))  # 调整图形大小

# 训练集和测试集的柱子
bars1 = ax.bar(x - width, train_metrics, width, label='Train')  
bars2 = ax.bar(x, valid_metrics, width, label='Valid')        
bars3 = ax.bar(x + width, test_metrics, width, label='Test',color="#31a354")   


# 添加标签和标题
ax.set_ylabel('Scores')
ax.set_title('Comparison of Train, Valid and Test Set Metrics')
ax.set_xticks(x)
ax.set_xticklabels(metrics_labels)  
ax.legend(loc='upper left')

# 在每个柱子上显示数值
def autolabel(bars):
    """在每个柱子上显示数值."""
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(round(height, 4)),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 5),  # 3 点垂直偏移
                    textcoords="offset points",
                    ha='center', va='bottom',
                    )  # 缩小字体)

autolabel(bars1)
autolabel(bars2)
autolabel(bars3)

fig.tight_layout()
plt.savefig("Comparison of Train, Valid and Test Set Metrics.pdf", format='pdf',bbox_inches='tight')
plt.show()

# %%
##问题？需不需要增加验证集的评价指标

# %% [markdown]
# ## 2.获取特征重要性(第一种方法)

# %%
import numpy as np

# %% [markdown]
# model.feature_importances_ 在使用 XGBoost 或其他决策树模型时，通常返回的是特征的重要性得分，这些得分基于各个特征在构建树时对模型预测误差的改进程度。这些重要性得分是通过计算特征在树中使用时对预测准确性的贡献或是分裂所减少的不纯度（例如 Gini 不纯度或均方误差）来得出的。然而，这不是 SHAP（SHapley Additive exPlanations）值。SHAP 值是基于博弈论中的 Shapley 值来解释模型预测的一个方法。它考虑了所有可能的特征组合来决定每个特征对于给定预测的贡献度。SHAP 值可以提供比传统特征重要性更深入、更细致的解释，因为它不仅表明了特征的重要性，还显示了特征值如何影响模型的输出。

# %%
# 获取XGBoost模型的特征贡献度（重要性）
feature_importances = model.feature_importances_

# %%
sorted_indices = np.argsort(feature_importances)[::-1]  # 逆序排列，重要性从高到低
sorted_features = train_x.columns[sorted_indices]
sorted_importances = feature_importances[sorted_indices]

# %%
for feature_name, importance in zip(sorted_features, sorted_importances):    
    print(f"Feature: {feature_name}, Importance: {importance:.4f}")
# Out:
# Feature: Mean Blood Glucose in Previous 24h, Importance: 0.5613
# Feature: Previous Blood Glucose Level, Importance: 0.2042
# Feature: Second Previous Blood Glucose Level, Importance: 0.1773
# Feature: Maximum Blood Glucose, Importance: 0.0259
# Feature: Minimum Blood Glucose, Importance: 0.0222
# Feature: Number of Hyperglycemia Episodes, Importance: 0.0050
# Feature: Gender, Importance: 0.0017
# Feature: Age, Importance: 0.0012
# Feature: Number of Hypoglycemia Episodes, Importance: 0.0011

# %%
import matplotlib.pyplot as plt

# 绘制按重要性排序的特征贡献性柱状图
plt.figure(figsize=(8,4), dpi=300)  # 设置图表尺寸和分辨率
plt.barh(sorted_features, sorted_importances, color='steelblue')  # 绘制水平柱状图
plt.xlabel('Importance', fontsize=14)  # 设置 x 轴标签
plt.ylabel('Features', fontsize=14)  # 设置 y 轴标签
plt.title('Sorted Feature Importance', fontsize=16)  # 设置图表标题
plt.gca().invert_yaxis()  # 反转 y 轴，使重要性高的特征在上方

plt.show()  # 显示图表

# %%
import shap
# 构建 shap解释器
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(test_x)


# 特征标签
labels = test_x.columns
plt.rcParams['font.family'] = 'SimHei'  # 或 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示为方块的问题
plt.rcParams['font.size'] = 13

# 绘制SHAP值总结图（Summary Plot）
plt.figure(figsize=(20, 5))
shap.summary_plot(shap_values, test_x, plot_type="bar", show=False)#默认情况下只会显示影响最大的前20 个特征
plt.title("test_x")
plt.xlabel('')  
plt.tight_layout()
plt.show()


###注意展示的不是文献所需的特征贡献图，SHAP值是一种解释模型预测的方法，通过计算每个特征对预测结果的贡献度，我们可以了解哪些特征对模型的影响最大，并依据这些贡献度来排序特征，从而筛选出重要特征

# %% [markdown]
# 测试集（test_x）是用于评估模型泛化性能的数据集。在模型训练完成后，用未见过的数据（即测试集）来评估其性能。
# 在使用 SHAP（SHapley Additive exPlanations）进行解释时，通常我们会基于测试集计算 SHAP 值，因为我们想知道模型在未见过的数据上的表现及其背后的解释。
# 这种方式可以告诉我们模型在真实场景或新数据上对每个特征的依赖程度。

# %% [markdown]
# SHAP值是一种解释模型预测的方法，通过计算每个特征对预测结果的贡献度，我们可以了解哪些特征对模型的影响最大，并依据这些贡献度来排序特征，从而筛选出重要特征

# %% [markdown]
# 使用sorted_indices重新排列数据集的特征，使得最重要的特征排在前面，这样排列后的数据集便于后续在不同特征组合下评估模型性能，特别是在进行逐步特征添加和蒙特卡洛模拟时，可以优先考虑贡献度大的特征

# %% [markdown]
# ## 3.回归结果可视化

# %%
import seaborn as sns
from sklearn import metrics

# %%
y_pred_train = model.predict(train_x)

# %%
# 创建一个包含训练集和测试集真实值与预测值的数据框
data_train = pd.DataFrame({
    'True': train_y,
    'Predicted': y_pred_train,
    'Data Set': 'Train'
})

data_test = pd.DataFrame({
    'True': test_y,
    'Predicted': y_pred_test,
    'Data Set': 'Test'
})

data = pd.concat([data_train, data_test])

# %%
print(f"train_y length: {len(train_y)}")
print(f"y_pred_train length: {len(y_pred_train)}")

print(f"test_y length: {len(test_y)}")
print(f"y_pred_test length: {len(y_pred_test)}")
# Out:
# train_y length: 29816
# y_pred_train length: 29816
# test_y length: 9939
# y_pred_test length: 9939

# %%
# 自定义调色板
palette = {'Train': '#b4d4e1', 'Test': '#f4ba8a'}

# %%
# 创建 JointGrid 对象
plt.figure(figsize=(8,6 ), dpi=300)
g = sns.JointGrid(data=data, x="True", y="Predicted", hue="Data Set", height=10, palette=palette)
# 绘制中心的散点图
g.plot_joint(sns.scatterplot, alpha=0.5)
# 添加训练集的回归线
sns.regplot(data=data_train, x="True", y="Predicted", scatter=False, ax=g.ax_joint, color='#b4d4e1', label='Train Regression Line')
# 添加测试集的回归线
sns.regplot(data=data_test, x="True", y="Predicted", scatter=False, ax=g.ax_joint, color='#f4ba8a', label='Test Regression Line')
# 添加边缘的柱状图
g.plot_marginals(sns.histplot, kde=False, element='bars', multiple='stack', alpha=0.5)
# 添加拟合优度文本在右下角
ax = g.ax_joint
ax.text(0.95, 0.1, f'Train $R^2$ = {R2_train:.4f}', transform=ax.transAxes, fontsize=12,
        verticalalignment='bottom', horizontalalignment='right', bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))
ax.text(0.95, 0.05, f'Test $R^2$ = {R2_test:.4f}', transform=ax.transAxes, fontsize=12,
        verticalalignment='bottom', horizontalalignment='right', bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))
# 在左上角添加模型名称文本
ax.text(0.75, 0.99, 'Model = xgboost', transform=ax.transAxes, fontsize=12,
        verticalalignment='top', horizontalalignment='left', bbox=dict(boxstyle="round,pad=0.3", edgecolor="black", facecolor="white"))
# 添加中心线
ax.plot([data['True'].min(), data['True'].max()], [data['True'].min(), data['True'].max()], c="black", alpha=0.5, linestyle='--', label='x=y')
ax.legend()
plt.savefig("TrueFalse.pdf", format='pdf', bbox_inches='tight')

# 关闭 y 轴的边缘柱状图
#g.ax_marg_y.set_visible(False)
plt.show()
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# D:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## 4.测试值和预测值可视化

# %%
# 计算测试集残差和标准差（使用 ddof=1 来计算样本标准差）
residuals_simulated = test_y -y_pred_test
sigma_simulated = np.std(residuals_simulated, ddof=1)

# %%
# 计算三种置信区间
conf_intervals_simulated = {
    'mu ± sigma': (y_pred_test - sigma_simulated, y_pred_test + sigma_simulated),
    'mu ± 2sigma': (y_pred_test - 2*sigma_simulated, y_pred_test + 2*sigma_simulated),
    'mu ± 3sigma': (y_pred_test - 3*sigma_simulated, y_pred_test + 3*sigma_simulated),
}

# %%
# 模拟数据加载和降采样操作

test_indices_simulated = np.arange(len(test_y))  # 模拟的索引数组

# 选择每100个点中的一个点进行绘图,全放进去太复杂
sample_rate = 150
test_indices_sampled = test_indices_simulated[::sample_rate]
test_y_sampled = test_y[::sample_rate]
y_pred_test_sampled = y_pred_test[::sample_rate]

# 置信区间数据降采样
sigma_lower_sampled = conf_intervals_simulated['mu ± sigma'][0][::sample_rate]
sigma_upper_sampled = conf_intervals_simulated['mu ± sigma'][1][::sample_rate]
sigma_2_lower_sampled = conf_intervals_simulated['mu ± 2sigma'][0][::sample_rate]
sigma_2_upper_sampled = conf_intervals_simulated['mu ± 2sigma'][1][::sample_rate]
sigma_3_lower_sampled = conf_intervals_simulated['mu ± 3sigma'][0][::sample_rate]
sigma_3_upper_sampled = conf_intervals_simulated['mu ± 3sigma'][1][::sample_rate]

# 绘制可视化图像
plt.figure(figsize=(20, 5), dpi=300)  # 设置图形大小和分辨率

# 绘制测试数据
plt.scatter(test_indices_sampled, test_y_sampled, color='red', label='Test data', zorder=5)

# 绘制预测均值
plt.plot(test_indices_sampled, y_pred_test_sampled, color='blue', label='Prediction, $\\mu$', zorder=4)

# 绘制三种置信区间
plt.fill_between(test_indices_sampled, sigma_lower_sampled, sigma_upper_sampled, 
                 color='navy', alpha=0.6, label='$\\mu \\pm \\sigma$')
plt.fill_between(test_indices_sampled, sigma_2_lower_sampled, sigma_2_upper_sampled, 
                 color='deepskyblue', alpha=0.5, label='$\\mu \\pm 2\\sigma$')
plt.fill_between(test_indices_sampled, sigma_3_lower_sampled, sigma_3_upper_sampled, 
                 color='lightblue', alpha=0.3, label='$\\mu \\pm 3\\sigma$')

# 设置图表标题和标签
plt.title('Test Data with Prediction and Confidence Intervals (XGBoost Model)')
plt.xlabel('Test Sample')
plt.ylabel('Simulated Output')
plt.legend(loc='upper right')  # 调整图例位置
plt.grid(True)  # 添加网格
plt.savefig("Test Data with Prediction and Confidence Intervals (XGBoost Model).pdf", bbox_inches='tight')  # 保存图像
plt.show()  # 显示图像
